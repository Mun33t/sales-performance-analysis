# %%
import sys
sys.version
# Out:
# '3.12.2 | packaged by conda-forge | (main, Feb 16 2024, 20:54:21) [Clang 16.0.6 ]'

# %%
import pandas as pd

df = pd.read_csv("/Users/admin/Documents/GitHub/sales-performance-analysis/data/Sample - Superstore.csv", encoding="latin1")
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
region_summary = (
    df.groupby("Region")[["Sales", "Profit"]]
    .sum()
    .sort_values(by="Sales", ascending=False)
)

region_summary
# Out:
#                Sales       Profit
# Region
# West     725457.8245  108418.4489
# East     678781.2400   91522.7800
# Central  501239.8908   39706.3625
# South    391721.9050   46749.4303

# %% [markdown]
# ### Insight 1: Regional Performance
#
# The West region leads in both total sales and total profit, indicating that it is the strongest-performing region and a key driver of overall business performance.

# %%
sales_by_region = (
    df.groupby
)

# %%
import matplotlib.pyplot as plt

region_summary["Sales"].plot(kind="bar")
plt.title("Total Sales by Region")
plt.ylabel("Total Sales")
plt.xlabel("Region")
plt.tight_layout()
plt.show()

# %% [markdown]
# The bar chart visually confirms that the West region outperforms all other regions in total sales, reinforcing its role as the primary revenue driver for the business.
